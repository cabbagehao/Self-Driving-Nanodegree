# %% [markdown]
# ### 稍微复杂一点的tensorflow教程
# 使用了卷积/dropout等.

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
import tensorflow as tf
sess = tf.InteractiveSession()

# %%
x = tf.placeholder("float", shape=[None, 784])
y_ = tf.placeholder("float", shape=[None, 10])

w = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

# %%
sess.run(tf.global_variables_initializer())

# %%
y = tf.nn.softmax(tf.matmul(x, w) + b)

# %%
cross_entropy = -tf.reduce_sum(y_ * tf.log(y))

# %%
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cross_entropy)

# %%
for i in range(1000):
  batch = mnist.train.next_batch(50)
  train_step.run(feed_dict={x: batch[0], y_: batch[1]})

# %%
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
print(accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# 0.9131

# %% [markdown]
# def weight_variable(shape):
#     initial = tf.truncated_normal(shape, stddev=0.1)
#     return tf.Variable(initial)
#
# def bias_variable(shape):
#     initial = tf.constant(0.1, shape=shape)
#     return tf.Variable(initial)

# %%
def conv2d(x, w):
    return tf.nn.conv2d(x, w, strides=[1,1,1,1], padding="SAME")

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1],
                          strides=[1,2,2,1], padding='SAME')

# %% [markdown]
# ### 第1层卷积

# %%
w_conv1 = weight_variable([5,5,1,32])
b_conv1 = bias_variable([32])

# %%
x_image = tf.reshape(x, [-1, 28,28,1])

# %%
h_conv1 = tf.nn.relu(conv2d(x_image, w_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# %% [markdown]
# ### 第2层卷积

# %%
w_conv2 = weight_variable([5,5,32,64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, w_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# %% [markdown]
# ### 密集连接层

# %%
w_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1))

# %% [markdown]
# #### Dropout 减少过拟合

# %%
keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# %% [markdown]
# ### 输出层

# %%
w_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, w_fc2) + b_fc2)

# %% [markdown]
# ### 训练和评估

# %%
cross_entropy = -tf.reduce_sum(y_ * tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())
for i in range(200000):
    batch = mnist.train.next_batch(50)
    if i%100 == 0:
        train_accuracy = accuracy.eval(feed_dict={
            x:batch[0], y_:batch[1], keep_prob:1.0})
        print("step %d, training accuracy %g" %(i, train_accuracy))
    train_step.run(feed_dict={x:batch[0], y_:batch[1], keep_prob:0.5})

print("test accuravy %g" %accuracy.eval(feed_dict={
    x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0
}))
# Out:
# step 0, training accuracy 0.16
# step 100, training accuracy 0.8
# step 200, training accuracy 0.9
# step 300, training accuracy 0.86
# step 400, training accuracy 0.9
# step 500, training accuracy 0.98
# step 600, training accuracy 0.98
# step 700, training accuracy 0.94
# step 800, training accuracy 0.94
# step 900, training accuracy 0.96
# step 1000, training accuracy 0.96
# step 1100, training accuracy 0.98
# step 1200, training accuracy 0.96
# step 1300, training accuracy 1
# step 1400, training accuracy 1
# step 1500, training accuracy 0.98
# step 1600, training accuracy 0.96
# step 1700, training accuracy 1
# step 1800, training accuracy 0.96
# step 1900, training accuracy 0.98
# step 2000, training accuracy 1
# step 2100, training accuracy 1
# step 2200, training accuracy 0.98
# step 2300, training accuracy 0.98
# step 2400, training accuracy 1
# step 2500, training accuracy 0.98
# step 2600, training accuracy 0.96
# step 2700, training accuracy 0.96
# step 2800, training accuracy 0.98
# step 2900, training accuracy 0.98
# step 3000, training accuracy 0.98
# step 3100, training accuracy 1
# step 3200, training accuracy 0.96
# step 3300, training accuracy 1
# step 3400, training accuracy 0.98
# step 3500, training accuracy 1
# step 3600, training accuracy 1
# step 3700, training accuracy 0.96
# step 3800, training accuracy 0.98
# step 3900, training accuracy 1
# step 4000, training accuracy 0.98
# step 4100, training accuracy 0.96
# step 4200, training accuracy 1
# step 4300, training accuracy 1
# step 4400, training accuracy 0.96
# step 4500, training accuracy 1
# step 4600, training accuracy 1
# step 4700, training accuracy 1
# step 4800, training accuracy 0.98
# step 4900, training accuracy 1
# step 5000, training accuracy 1
# step 5100, training accuracy 0.98
# step 5200, training accuracy 0.98
# step 5300, training accuracy 0.96
# step 5400, training accuracy 0.98
# step 5500, training accuracy 0.98
# step 5600, training accuracy 0.98
# step 5700, training accuracy 1
# step 5800, training accuracy 1
# step 5900, training accuracy 1
# step 6000, training accuracy 1
# step 6100, training accuracy 1
# step 6200, training accuracy 0.98
# step 6300, training accuracy 0.98
# step 6400, training accuracy 1
# step 6500, training accuracy 1
# step 6600, training accuracy 1
# step 6700, training accuracy 0.98
# step 6800, training accuracy 0.98
# step 6900, training accuracy 1
# step 7000, training accuracy 1
# step 7100, training accuracy 1
# step 7200, training accuracy 0.98
# step 7300, training accuracy 1
# step 7400, training accuracy 1
# step 7500, training accuracy 1
# step 7600, training accuracy 1
# step 7700, training accuracy 1
# step 7800, training accuracy 1
# step 7900, training accuracy 1
# step 8000, training accuracy 1
# step 8100, training accuracy 0.98
# step 8200, training accuracy 1
# step 8300, training accuracy 1
# step 8400, training accuracy 1
# step 8500, training accuracy 1
# step 8600, training accuracy 0.98
# step 8700, training accuracy 1
# step 8800, training accuracy 1
# step 8900, training accuracy 1
# step 9000, training accuracy 1
# step 9100, training accuracy 1
# step 9200, training accuracy 1
# step 9300, training accuracy 1
# step 9400, training accuracy 1
# step 9500, training accuracy 1
# step 9600, training accuracy 0.98
# step 9700, training accuracy 0.98
# step 9800, training accuracy 1
# step 9900, training accuracy 1
# step 10000, training accuracy 1
# step 10100, training accuracy 1
# step 10200, training accuracy 1
# step 10300, training accuracy 1
# step 10400, training accuracy 0.98
# step 10500, training accuracy 1
# step 10600, training accuracy 1
# step 10700, training accuracy 1
# step 10800, training accuracy 1
# step 10900, training accuracy 1
# step 11000, training accuracy 1
# step 11100, training accuracy 1
# step 11200, training accuracy 1
# step 11300, training accuracy 1
# step 11400, training accuracy 1
# step 11500, training accuracy 1
# step 11600, training accuracy 1
# step 11700, training accuracy 1
# step 11800, training accuracy 1
# step 11900, training accuracy 1
# step 12000, training accuracy 1
# step 12100, training accuracy 1
# step 12200, training accuracy 1
# step 12300, training accuracy 1
# step 12400, training accuracy 1
# step 12500, training accuracy 1
# step 12600, training accuracy 1
# step 12700, training accuracy 1
# step 12800, training accuracy 1
# step 12900, training accuracy 1
# step 13000, training accuracy 1
# step 13100, training accuracy 1
# step 13200, training accuracy 1
# step 13300, training accuracy 0.98
# step 13400, training accuracy 1
# step 13500, training accuracy 1
# step 13600, training accuracy 1
# step 13700, training accuracy 1
# step 13800, training accuracy 1
# step 13900, training accuracy 1
# step 14000, training accuracy 1
# step 14100, training accuracy 1
# step 14200, training accuracy 1
# step 14300, training accuracy 1
# step 14400, training accuracy 1
# step 14500, training accuracy 1
# step 14600, training accuracy 1
# step 14700, training accuracy 1
# step 14800, training accuracy 1
# step 14900, training accuracy 1
# step 15000, training accuracy 0.98
# step 15100, training accuracy 1
# step 15200, training accuracy 1
# step 15300, training accuracy 1
# step 15400, training accuracy 1
# step 15500, training accuracy 1
# step 15600, training accuracy 1
# step 15700, training accuracy 1
# step 15800, training accuracy 1
# step 15900, training accuracy 1
# step 16000, training accuracy 1
# step 16100, training accuracy 1
# step 16200, training accuracy 1
# step 16300, training accuracy 1
# step 16400, training accuracy 1
# step 16500, training accuracy 1
# step 16600, training accuracy 1
# step 16700, training accuracy 0.98
# step 16800, training accuracy 1
# step 16900, training accuracy 1
# step 17000, training accuracy 1
# step 17100, training accuracy 0.98
# step 17200, training accuracy 1
# step 17300, training accuracy 1
# step 17400, training accuracy 1
# step 17500, training accuracy 1
# step 17600, training accuracy 1
# step 17700, training accuracy 1
# step 17800, training accuracy 1
# step 17900, training accuracy 1
# step 18000, training accuracy 1
# step 18100, training accuracy 1
# step 18200, training accuracy 1
# step 18300, training accuracy 1
# step 18400, training accuracy 1
# step 18500, training accuracy 1
# step 18600, training accuracy 1
# step 18700, training accuracy 1
# step 18800, training accuracy 1
# step 18900, training accuracy 1
# step 19000, training accuracy 1
# step 19100, training accuracy 1
# step 19200, training accuracy 1
# step 19300, training accuracy 1
# step 19400, training accuracy 1
# step 19500, training accuracy 1
# step 19600, training accuracy 1
# step 19700, training accuracy 1
# step 19800, training accuracy 1
# step 19900, training accuracy 1
# step 20000, training accuracy 1
# step 20100, training accuracy 1
# step 20200, training accuracy 1
# step 20300, training accuracy 1
# step 20400, training accuracy 1
# step 20500, training accuracy 1
# step 20600, training accuracy 0.98
# step 20700, training accuracy 1
# step 20800, training accuracy 1
# step 20900, training accuracy 1
# step 21000, training accuracy 1
# step 21100, training accuracy 1
# step 21200, training accuracy 1
# step 21300, training accuracy 1
# step 21400, training accuracy 1
# step 21500, training accuracy 1
# step 21600, training accuracy 1
# step 21700, training accuracy 1
# step 21800, training accuracy 1
# step 21900, training accuracy 1
# step 22000, training accuracy 1
# step 22100, training accuracy 1
# step 22200, training accuracy 1
# step 22300, training accuracy 1
# step 22400, training accuracy 1
# step 22500, training accuracy 1
# step 22600, training accuracy 1
# step 22700, training accuracy 1
# step 22800, training accuracy 1
# step 22900, training accuracy 1
# step 23000, training accuracy 1
# step 23100, training accuracy 1
# step 23200, training accuracy 1
# step 23300, training accuracy 1
# step 23400, training accuracy 0.98
# step 23500, training accuracy 1
# step 23600, training accuracy 1
# step 23700, training accuracy 1
# step 23800, training accuracy 1
# step 23900, training accuracy 1
# step 24000, training accuracy 1
# step 24100, training accuracy 1
# step 24200, training accuracy 1
# step 24300, training accuracy 1
# step 24400, training accuracy 1
# step 24500, training accuracy 1
# step 24600, training accuracy 1
# step 24700, training accuracy 1
# step 24800, training accuracy 1
# step 24900, training accuracy 1
# step 25000, training accuracy 1
# step 25100, training accuracy 1
# step 25200, training accuracy 1
# step 25300, training accuracy 1
# step 25400, training accuracy 1
# step 25500, training accuracy 1
# step 25600, training accuracy 1
# step 25700, training accuracy 1
# step 25800, training accuracy 1
# step 25900, training accuracy 1
# step 26000, training accuracy 1
# step 26100, training accuracy 1
# step 26200, training accuracy 1
# step 26300, training accuracy 1
# step 26400, training accuracy 1
# step 26500, training accuracy 1
# step 26600, training accuracy 1
# step 26700, training accuracy 1
# step 26800, training accuracy 1
# step 26900, training accuracy 1
# step 27000, training accuracy 1
# step 27100, training accuracy 1
# step 27200, training accuracy 1
# step 27300, training accuracy 1
# step 27400, training accuracy 1
# step 27500, training accuracy 1
# step 27600, training accuracy 1
# step 27700, training accuracy 1
# step 27800, training accuracy 1
# step 27900, training accuracy 1
# step 28000, training accuracy 1
# step 28100, training accuracy 1
# step 28200, training accuracy 1
# step 28300, training accuracy 1
# step 28400, training accuracy 1
# step 28500, training accuracy 1
# step 28600, training accuracy 1
# step 28700, training accuracy 1
# step 28800, training accuracy 1
# step 28900, training accuracy 1
# step 29000, training accuracy 1
# step 29100, training accuracy 1
# step 29200, training accuracy 1
# step 29300, training accuracy 1
# step 29400, training accuracy 1
# step 29500, training accuracy 1
# step 29600, training accuracy 1
# step 29700, training accuracy 1
# step 29800, training accuracy 1
# step 29900, training accuracy 1
# step 30000, training accuracy 1
# step 30100, training accuracy 1
# step 30200, training accuracy 1
# step 30300, training accuracy 1
# step 30400, training accuracy 1
# step 30500, training accuracy 1
# step 30600, training accuracy 1
# step 30700, training accuracy 1
# step 30800, training accuracy 0.16
# step 30900, training accuracy 0.04
# step 31000, training accuracy 0.02
# step 31100, training accuracy 0.18
# step 31200, training accuracy 0.08
# step 31300, training accuracy 0.04
# step 31400, training accuracy 0.06
# step 31500, training accuracy 0.1
# step 31600, training accuracy 0.06
# step 31700, training accuracy 0.04
# step 31800, training accuracy 0.04
# step 31900, training accuracy 0.22
# step 32000, training accuracy 0.04
# step 32100, training accuracy 0.06
# step 32200, training accuracy 0.16
# step 32300, training accuracy 0.12
# step 32400, training accuracy 0.22
# step 32500, training accuracy 0.2
# step 32600, training accuracy 0.06
# step 32700, training accuracy 0.08
# step 32800, training accuracy 0.12
# step 32900, training accuracy 0.08
# step 33000, training accuracy 0.06
# step 33100, training accuracy 0.08
# step 33200, training accuracy 0.04
# step 33300, training accuracy 0.1
# step 33400, training accuracy 0.1
# step 33500, training accuracy 0.14
# step 33600, training accuracy 0.08
# step 33700, training accuracy 0.1
# step 33800, training accuracy 0.1
# step 33900, training accuracy 0.12
# step 34000, training accuracy 0.12
# step 34100, training accuracy 0.22
# step 34200, training accuracy 0.08
# step 34300, training accuracy 0.12
# step 34400, training accuracy 0.04
# step 34500, training accuracy 0
# step 34600, training accuracy 0.06
# step 34700, training accuracy 0.1
# step 34800, training accuracy 0.04
# step 34900, training accuracy 0.12
# step 35000, training accuracy 0.04
# step 35100, training accuracy 0.08
# step 35200, training accuracy 0.02
# step 35300, training accuracy 0.1
# step 35400, training accuracy 0.1
# step 35500, training accuracy 0.06
# step 35600, training accuracy 0.16
# step 35700, training accuracy 0.1
# step 35800, training accuracy 0.1
# step 35900, training accuracy 0.08
# step 36000, training accuracy 0.08
# step 36100, training accuracy 0.06
# step 36200, training accuracy 0.08
# step 36300, training accuracy 0.06
# step 36400, training accuracy 0.02
# step 36500, training accuracy 0.12
# step 36600, training accuracy 0.1
# step 36700, training accuracy 0.14
# step 36800, training accuracy 0.08
# step 36900, training accuracy 0.06
# step 37000, training accuracy 0.04
# step 37100, training accuracy 0.08
# step 37200, training accuracy 0.16
# step 37300, training accuracy 0.14
# step 37400, training accuracy 0.06
# step 37500, training accuracy 0.08
# step 37600, training accuracy 0.1
# step 37700, training accuracy 0.12
# step 37800, training accuracy 0.04
# step 37900, training accuracy 0.06
# step 38000, training accuracy 0.12
# step 38100, training accuracy 0.12
# step 38200, training accuracy 0.06
# step 38300, training accuracy 0.08
# step 38400, training accuracy 0.06
# step 38500, training accuracy 0.1
# step 38600, training accuracy 0.14
# step 38700, training accuracy 0.14
# step 38800, training accuracy 0.08
# step 38900, training accuracy 0.12
# step 39000, training accuracy 0.12
# step 39100, training accuracy 0.18
# step 39200, training accuracy 0.06
# step 39300, training accuracy 0.06
# step 39400, training accuracy 0.08
# step 39500, training accuracy 0.2
# step 39600, training accuracy 0.06
# step 39700, training accuracy 0.12
# step 39800, training accuracy 0.14
# step 39900, training accuracy 0.08
# step 40000, training accuracy 0.14
# step 40100, training accuracy 0.1
# step 40200, training accuracy 0.12
# step 40300, training accuracy 0.04
# step 40400, training accuracy 0.08
# step 40500, training accuracy 0.06
# step 40600, training accuracy 0.04
# step 40700, training accuracy 0.06
# step 40800, training accuracy 0.1
# step 40900, training accuracy 0.04
# step 41000, training accuracy 0.16
# step 41100, training accuracy 0.12
# step 41200, training accuracy 0.06
# step 41300, training accuracy 0.2
# step 41400, training accuracy 0.1
# step 41500, training accuracy 0.1
# step 41600, training accuracy 0.08
# step 41700, training accuracy 0.12
# step 41800, training accuracy 0.04
# step 41900, training accuracy 0.18
# step 42000, training accuracy 0.1
# step 42100, training accuracy 0.08
# step 42200, training accuracy 0.06
# step 42300, training accuracy 0.1
# step 42400, training accuracy 0.1
# step 42500, training accuracy 0.08
# step 42600, training accuracy 0.12
# step 42700, training accuracy 0.16
# step 42800, training accuracy 0.12
# step 42900, training accuracy 0.1
# step 43000, training accuracy 0.06
# step 43100, training accuracy 0.16
# step 43200, training accuracy 0.1
# step 43300, training accuracy 0.06
# step 43400, training accuracy 0.08
# step 43500, training accuracy 0.06
# step 43600, training accuracy 0.08
# step 43700, training accuracy 0.06
# step 43800, training accuracy 0.14
# step 43900, training accuracy 0.06
# step 44000, training accuracy 0.1
# step 44100, training accuracy 0.16
# step 44200, training accuracy 0.02
# step 44300, training accuracy 0.06
# step 44400, training accuracy 0.06
# step 44500, training accuracy 0.1
# step 44600, training accuracy 0.1
# step 44700, training accuracy 0.16
# step 44800, training accuracy 0.1
# step 44900, training accuracy 0.1
# step 45000, training accuracy 0.2
# step 45100, training accuracy 0.04
# step 45200, training accuracy 0.16
# step 45300, training accuracy 0.1
# step 45400, training accuracy 0.16
# step 45500, training accuracy 0.1
# step 45600, training accuracy 0.08
# step 45700, training accuracy 0.06
# step 45800, training accuracy 0.08
# step 45900, training accuracy 0.06
# step 46000, training accuracy 0.12
# step 46100, training accuracy 0.14
# step 46200, training accuracy 0.12
# step 46300, training accuracy 0.16
# step 46400, training accuracy 0.08
# step 46500, training accuracy 0.08
# step 46600, training accuracy 0.1
# step 46700, training accuracy 0.08
# step 46800, training accuracy 0.08
# step 46900, training accuracy 0.06
# step 47000, training accuracy 0.08
# step 47100, training accuracy 0.2
# step 47200, training accuracy 0.04
# step 47300, training accuracy 0.14
# step 47400, training accuracy 0.08
# step 47500, training accuracy 0.14
# step 47600, training accuracy 0.08
# step 47700, training accuracy 0.14
# step 47800, training accuracy 0.1
# step 47900, training accuracy 0.14
# step 48000, training accuracy 0.16
# step 48100, training accuracy 0.06
# step 48200, training accuracy 0.14
# step 48300, training accuracy 0.2
# step 48400, training accuracy 0.14
# step 48500, training accuracy 0.06
# step 48600, training accuracy 0.06
# step 48700, training accuracy 0.1
# step 48800, training accuracy 0.12
# step 48900, training accuracy 0.16
# step 49000, training accuracy 0.1
# step 49100, training accuracy 0.1
# step 49200, training accuracy 0.1
# step 49300, training accuracy 0.1
# step 49400, training accuracy 0.1
# step 49500, training accuracy 0.12
# step 49600, training accuracy 0.1
# step 49700, training accuracy 0.04
# step 49800, training accuracy 0.02
# step 49900, training accuracy 0.08
# step 50000, training accuracy 0.08
# step 50100, training accuracy 0.14
# step 50200, training accuracy 0.12
# step 50300, training accuracy 0.12
# step 50400, training accuracy 0.1
# step 50500, training accuracy 0.16
# step 50600, training accuracy 0.08
# step 50700, training accuracy 0.14
# step 50800, training accuracy 0.12
# step 50900, training accuracy 0.08
# step 51000, training accuracy 0.18
# step 51100, training accuracy 0.08
# step 51200, training accuracy 0.14
# step 51300, training accuracy 0.1
# step 51400, training accuracy 0.1
# step 51500, training accuracy 0.1
# step 51600, training accuracy 0.16
# step 51700, training accuracy 0.16
# step 51800, training accuracy 0.12
# step 51900, training accuracy 0.14
# step 52000, training accuracy 0.04
# step 52100, training accuracy 0.04
# step 52200, training accuracy 0.12
# step 52300, training accuracy 0.04
# step 52400, training accuracy 0.12
# step 52500, training accuracy 0.06
# step 52600, training accuracy 0.04
# step 52700, training accuracy 0.16
# step 52800, training accuracy 0.1
# step 52900, training accuracy 0.04
# step 53000, training accuracy 0.12
# step 53100, training accuracy 0.02
# step 53200, training accuracy 0.1
# step 53300, training accuracy 0.1
# step 53400, training accuracy 0.06
# step 53500, training accuracy 0.06
# step 53600, training accuracy 0.06
# step 53700, training accuracy 0.12
# step 53800, training accuracy 0.12
# step 53900, training accuracy 0.14
# step 54000, training accuracy 0.08
# step 54100, training accuracy 0.04
# step 54200, training accuracy 0.14
# step 54300, training accuracy 0.12
# step 54400, training accuracy 0.08
# step 54500, training accuracy 0.1
# step 54600, training accuracy 0.1
# step 54700, training accuracy 0.1
# step 54800, training accuracy 0.06
# step 54900, training accuracy 0.12
# step 55000, training accuracy 0.04
# step 55100, training accuracy 0.06
# step 55200, training accuracy 0.12
# step 55300, training accuracy 0.1
# step 55400, training accuracy 0.12
# step 55500, training accuracy 0.08
# step 55600, training accuracy 0.08
# step 55700, training accuracy 0.06
# step 55800, training accuracy 0.04
# step 55900, training accuracy 0.06
# step 56000, training accuracy 0.12
# step 56100, training accuracy 0.12
# step 56200, training accuracy 0.08
# step 56300, training accuracy 0.1
# step 56400, training accuracy 0.08
# step 56500, training accuracy 0.08
# step 56600, training accuracy 0.16
# step 56700, training accuracy 0.04
# step 56800, training accuracy 0.08
# step 56900, training accuracy 0.14
# step 57000, training accuracy 0.12
# step 57100, training accuracy 0.08
# step 57200, training accuracy 0.12
# step 57300, training accuracy 0.06
# step 57400, training accuracy 0.12
# step 57500, training accuracy 0.14
# step 57600, training accuracy 0.14
# step 57700, training accuracy 0.08
# step 57800, training accuracy 0.14
# step 57900, training accuracy 0
# step 58000, training accuracy 0.04
# step 58100, training accuracy 0.1
# step 58200, training accuracy 0.08
# step 58300, training accuracy 0.14
# step 58400, training accuracy 0.14
# step 58500, training accuracy 0.16
# step 58600, training accuracy 0.12
# step 58700, training accuracy 0.14
# step 58800, training accuracy 0.08
# step 58900, training accuracy 0.04
# step 59000, training accuracy 0.1
# step 59100, training accuracy 0.04
# step 59200, training accuracy 0.04
# step 59300, training accuracy 0.08
# step 59400, training accuracy 0.1
# step 59500, training accuracy 0.16
# step 59600, training accuracy 0.12
# step 59700, training accuracy 0.14
# step 59800, training accuracy 0.12
# step 59900, training accuracy 0.1
# step 60000, training accuracy 0.06
# step 60100, training accuracy 0.16
# step 60200, training accuracy 0.08
# step 60300, training accuracy 0.12
# step 60400, training accuracy 0.1
# step 60500, training accuracy 0.1
# step 60600, training accuracy 0.12
# step 60700, training accuracy 0.14
# step 60800, training accuracy 0.08
# step 60900, training accuracy 0.06
# step 61000, training accuracy 0.1
# step 61100, training accuracy 0.14
# step 61200, training accuracy 0.2
# step 61300, training accuracy 0.1
# step 61400, training accuracy 0.14
# step 61500, training accuracy 0.06
# step 61600, training accuracy 0.06
# step 61700, training accuracy 0.2
# step 61800, training accuracy 0.1
# step 61900, training accuracy 0.08
# step 62000, training accuracy 0.1
# step 62100, training accuracy 0.06
# step 62200, training accuracy 0.14
# step 62300, training accuracy 0.14
# step 62400, training accuracy 0.06
# step 62500, training accuracy 0.04
# step 62600, training accuracy 0.06
# step 62700, training accuracy 0.1
# step 62800, training accuracy 0.12
# step 62900, training accuracy 0.1
# step 63000, training accuracy 0.14
# step 63100, training accuracy 0.08
# step 63200, training accuracy 0.1
# step 63300, training accuracy 0.02
# step 63400, training accuracy 0.08
# step 63500, training accuracy 0.08
# step 63600, training accuracy 0.1
# step 63700, training accuracy 0.1
# step 63800, training accuracy 0.14
# step 63900, training accuracy 0.06
# step 64000, training accuracy 0.06
# step 64100, training accuracy 0.08
# step 64200, training accuracy 0.08
# step 64300, training accuracy 0.16
# step 64400, training accuracy 0.14
# step 64500, training accuracy 0.14
# step 64600, training accuracy 0.1
# step 64700, training accuracy 0.12
# step 64800, training accuracy 0.1
# step 64900, training accuracy 0.06
# step 65000, training accuracy 0.1
# step 65100, training accuracy 0.1
# step 65200, training accuracy 0.08
# step 65300, training accuracy 0.12
# step 65400, training accuracy 0.12
# step 65500, training accuracy 0.1
# step 65600, training accuracy 0.12
# step 65700, training accuracy 0.14
# step 65800, training accuracy 0.08
# step 65900, training accuracy 0.14
# step 66000, training accuracy 0.16
# step 66100, training accuracy 0.1
# step 66200, training accuracy 0.1
# step 66300, training accuracy 0.08
# step 66400, training accuracy 0.1
# step 66500, training accuracy 0.08
# step 66600, training accuracy 0.12
# step 66700, training accuracy 0.14
# step 66800, training accuracy 0.06
# step 66900, training accuracy 0.06
# step 67000, training accuracy 0.1
# step 67100, training accuracy 0.08
# step 67200, training accuracy 0.18
# step 67300, training accuracy 0.2
# step 67400, training accuracy 0.1
# step 67500, training accuracy 0.02
# step 67600, training accuracy 0.04
# step 67700, training accuracy 0.08
# step 67800, training accuracy 0.04
# step 67900, training accuracy 0.06
# step 68000, training accuracy 0.1
# step 68100, training accuracy 0.12
# step 68200, training accuracy 0.04
# step 68300, training accuracy 0.06
# step 68400, training accuracy 0.14
# step 68500, training accuracy 0.16
# step 68600, training accuracy 0.12
# step 68700, training accuracy 0.1
# step 68800, training accuracy 0.1
# step 68900, training accuracy 0.08
# step 69000, training accuracy 0.12
# step 69100, training accuracy 0.08
# step 69200, training accuracy 0.2
# step 69300, training accuracy 0.08
# step 69400, training accuracy 0.1
# step 69500, training accuracy 0.08
# step 69600, training accuracy 0.14
# step 69700, training accuracy 0.04
# step 69800, training accuracy 0.12
# step 69900, training accuracy 0.06
# step 70000, training accuracy 0.04
# step 70100, training accuracy 0.08
# step 70200, training accuracy 0.16
# step 70300, training accuracy 0.06
# step 70400, training accuracy 0.1
# step 70500, training accuracy 0.04
# step 70600, training accuracy 0.14
# step 70700, training accuracy 0.1
# step 70800, training accuracy 0.12
# step 70900, training accuracy 0.02
# step 71000, training accuracy 0.16
# step 71100, training accuracy 0.12
# step 71200, training accuracy 0.08
# step 71300, training accuracy 0.22
# step 71400, training accuracy 0.1
# step 71500, training accuracy 0.12
# step 71600, training accuracy 0.04
# step 71700, training accuracy 0.02
# step 71800, training accuracy 0.12
# step 71900, training accuracy 0.08
# step 72000, training accuracy 0.06
# step 72100, training accuracy 0.16
# step 72200, training accuracy 0.12
# step 72300, training accuracy 0.1
# step 72400, training accuracy 0.08
# step 72500, training accuracy 0.14
# step 72600, training accuracy 0.16
# step 72700, training accuracy 0.12
# step 72800, training accuracy 0.08
# step 72900, training accuracy 0.08
# step 73000, training accuracy 0.08
# step 73100, training accuracy 0.06
# step 73200, training accuracy 0.08
# step 73300, training accuracy 0.08
# step 73400, training accuracy 0.14
# step 73500, training accuracy 0.14
# step 73600, training accuracy 0.22
# step 73700, training accuracy 0.1
# step 73800, training accuracy 0.08
# step 73900, training accuracy 0.12
# step 74000, training accuracy 0.04
# step 74100, training accuracy 0.12
# step 74200, training accuracy 0.08
# step 74300, training accuracy 0.12
# step 74400, training accuracy 0.06
# step 74500, training accuracy 0.08
# step 74600, training accuracy 0.12
# step 74700, training accuracy 0.04
# step 74800, training accuracy 0.02
# step 74900, training accuracy 0.14
# step 75000, training accuracy 0.1
# step 75100, training accuracy 0.12
# step 75200, training accuracy 0.02
# step 75300, training accuracy 0.14
# step 75400, training accuracy 0.1
# step 75500, training accuracy 0.06
# step 75600, training accuracy 0.06
# step 75700, training accuracy 0.1
# step 75800, training accuracy 0.08
# step 75900, training accuracy 0.06
# step 76000, training accuracy 0.06
# step 76100, training accuracy 0.14
# step 76200, training accuracy 0.08
# step 76300, training accuracy 0.1
# step 76400, training accuracy 0.1
# step 76500, training accuracy 0.1
# step 76600, training accuracy 0.1
# step 76700, training accuracy 0.14
# step 76800, training accuracy 0.16
# step 76900, training accuracy 0.06
# step 77000, training accuracy 0.04
# step 77100, training accuracy 0.12
# step 77200, training accuracy 0.02
# step 77300, training accuracy 0.12
# step 77400, training accuracy 0.1
# step 77500, training accuracy 0.16
# step 77600, training accuracy 0.1
# step 77700, training accuracy 0.16
# step 77800, training accuracy 0.12
# step 77900, training accuracy 0.14
# step 78000, training accuracy 0.06
# step 78100, training accuracy 0.06
# step 78200, training accuracy 0.02
# step 78300, training accuracy 0.08
# step 78400, training accuracy 0.08
# step 78500, training accuracy 0.12
# step 78600, training accuracy 0.04
# step 78700, training accuracy 0.12
# step 78800, training accuracy 0.12
# step 78900, training accuracy 0.14
# step 79000, training accuracy 0.14
# step 79100, training accuracy 0.16
# step 79200, training accuracy 0.1
# step 79300, training accuracy 0.14
# step 79400, training accuracy 0.08
# step 79500, training accuracy 0.02
# step 79600, training accuracy 0.1
# step 79700, training accuracy 0.14
# step 79800, training accuracy 0.06
# step 79900, training accuracy 0.18
# step 80000, training accuracy 0.06
# step 80100, training accuracy 0.12
# step 80200, training accuracy 0.12
# step 80300, training accuracy 0.02
# step 80400, training accuracy 0.06
# step 80500, training accuracy 0.14
# step 80600, training accuracy 0.08
# step 80700, training accuracy 0.12
# step 80800, training accuracy 0.06
# step 80900, training accuracy 0.08
# step 81000, training accuracy 0.1
# step 81100, training accuracy 0.1
# step 81200, training accuracy 0.06
# step 81300, training accuracy 0.06
# step 81400, training accuracy 0.1
# step 81500, training accuracy 0.08
# step 81600, training accuracy 0.1
# step 81700, training accuracy 0.12
# step 81800, training accuracy 0.12
# step 81900, training accuracy 0.04
# step 82000, training accuracy 0.04
# step 82100, training accuracy 0.14
# step 82200, training accuracy 0.06
# step 82300, training accuracy 0.1
# step 82400, training accuracy 0.16
# step 82500, training accuracy 0.14
# step 82600, training accuracy 0.12
# step 82700, training accuracy 0.06
# step 82800, training accuracy 0.1
# step 82900, training accuracy 0.14
# step 83000, training accuracy 0.2
# step 83100, training accuracy 0.16
# step 83200, training accuracy 0.12
# step 83300, training accuracy 0.04
# step 83400, training accuracy 0.12
# step 83500, training accuracy 0.2
# step 83600, training accuracy 0.14
# step 83700, training accuracy 0.06
# step 83800, training accuracy 0.1
# step 83900, training accuracy 0.06
# step 84000, training accuracy 0.14
# step 84100, training accuracy 0.14
# step 84200, training accuracy 0.16
# step 84300, training accuracy 0.04
# step 84400, training accuracy 0.06
# step 84500, training accuracy 0.14
# step 84600, training accuracy 0.08
# step 84700, training accuracy 0.1
# step 84800, training accuracy 0.08
# step 84900, training accuracy 0.12
# step 85000, training accuracy 0.08
# step 85100, training accuracy 0.04
# step 85200, training accuracy 0.16
# step 85300, training accuracy 0.06
# step 85400, training accuracy 0.16
# step 85500, training accuracy 0.16
# step 85600, training accuracy 0.06
# step 85700, training accuracy 0.14
# step 85800, training accuracy 0.02
# step 85900, training accuracy 0.02
# step 86000, training accuracy 0.08
# step 86100, training accuracy 0.08
# step 86200, training accuracy 0.1
# step 86300, training accuracy 0.16
# step 86400, training accuracy 0.06
# step 86500, training accuracy 0.12
# step 86600, training accuracy 0.04
# step 86700, training accuracy 0.08
# step 86800, training accuracy 0.16
# step 86900, training accuracy 0.14
# step 87000, training accuracy 0.08
# step 87100, training accuracy 0.16
# step 87200, training accuracy 0.2
# step 87300, training accuracy 0.08
# step 87400, training accuracy 0.12
# step 87500, training accuracy 0.08
# step 87600, training accuracy 0.08
# step 87700, training accuracy 0.06
# step 87800, training accuracy 0.12
# step 87900, training accuracy 0.12
# step 88000, training accuracy 0.1
# step 88100, training accuracy 0.06
# step 88200, training accuracy 0.12
# step 88300, training accuracy 0.18
# step 88400, training accuracy 0.12
# step 88500, training accuracy 0.16
# step 88600, training accuracy 0.1
# step 88700, training accuracy 0.12
# step 88800, training accuracy 0.14
# step 88900, training accuracy 0.08
# step 89000, training accuracy 0.1
# step 89100, training accuracy 0.16
# step 89200, training accuracy 0.02
# step 89300, training accuracy 0.08
# step 89400, training accuracy 0.12
# step 89500, training accuracy 0.12
# step 89600, training accuracy 0.08
# step 89700, training accuracy 0.08
# step 89800, training accuracy 0.12
# step 89900, training accuracy 0.12
# step 90000, training accuracy 0.16
# step 90100, training accuracy 0.1
# step 90200, training accuracy 0.1
# step 90300, training accuracy 0.14
# step 90400, training accuracy 0.1
# step 90500, training accuracy 0.02
# step 90600, training accuracy 0.16
# step 90700, training accuracy 0.08
# step 90800, training accuracy 0.08
# step 90900, training accuracy 0.08
# step 91000, training accuracy 0.04
# step 91100, training accuracy 0.14
# step 91200, training accuracy 0.2
# step 91300, training accuracy 0.1
# step 91400, training accuracy 0.14
# step 91500, training accuracy 0.08
# step 91600, training accuracy 0.08
# step 91700, training accuracy 0.1
# step 91800, training accuracy 0.08
# step 91900, training accuracy 0.08
# step 92000, training accuracy 0.08
# step 92100, training accuracy 0.12
# step 92200, training accuracy 0.1
# step 92300, training accuracy 0.08
# step 92400, training accuracy 0.04
# step 92500, training accuracy 0.16
# step 92600, training accuracy 0.06
# step 92700, training accuracy 0.14
# step 92800, training accuracy 0.14
# step 92900, training accuracy 0.08
# step 93000, training accuracy 0.18
# step 93100, training accuracy 0.04
# step 93200, training accuracy 0.1
# step 93300, training accuracy 0.02
# step 93400, training accuracy 0.12
# step 93500, training accuracy 0.04
# step 93600, training accuracy 0.06
# step 93700, training accuracy 0.14
# step 93800, training accuracy 0.1
# step 93900, training accuracy 0.1
# step 94000, training accuracy 0.02
# step 94100, training accuracy 0.06
# step 94200, training accuracy 0.14
# step 94300, training accuracy 0.12
# step 94400, training accuracy 0.12
# step 94500, training accuracy 0.1
# step 94600, training accuracy 0.16
# step 94700, training accuracy 0.18
# step 94800, training accuracy 0.12
# step 94900, training accuracy 0.08
# step 95000, training accuracy 0.08
# step 95100, training accuracy 0.08
# step 95200, training accuracy 0.08
# step 95300, training accuracy 0.1
# step 95400, training accuracy 0.04
# step 95500, training accuracy 0.04
# step 95600, training accuracy 0.04
# step 95700, training accuracy 0.14
# step 95800, training accuracy 0.18
# step 95900, training accuracy 0.04
# step 96000, training accuracy 0.12
# step 96100, training accuracy 0.12
# step 96200, training accuracy 0.14
# step 96300, training accuracy 0.14
# step 96400, training accuracy 0.14
# step 96500, training accuracy 0.06
# step 96600, training accuracy 0.08
# step 96700, training accuracy 0.04
# step 96800, training accuracy 0.1
# step 96900, training accuracy 0.12
# step 97000, training accuracy 0.12
# step 97100, training accuracy 0.08
# step 97200, training accuracy 0.14
# step 97300, training accuracy 0.06
# step 97400, training accuracy 0.06
# step 97500, training accuracy 0.16
# step 97600, training accuracy 0.06
# step 97700, training accuracy 0.08
# step 97800, training accuracy 0.04
# step 97900, training accuracy 0.04
# step 98000, training accuracy 0.08
# step 98100, training accuracy 0.08
# step 98200, training accuracy 0.12
# step 98300, training accuracy 0.08
# step 98400, training accuracy 0.1
# step 98500, training accuracy 0.1
# step 98600, training accuracy 0.1
# step 98700, training accuracy 0.14
# step 98800, training accuracy 0.06
# step 98900, training accuracy 0.1
# step 99000, training accuracy 0.16
# step 99100, training accuracy 0.18
# step 99200, training accuracy 0.02
# step 99300, training accuracy 0.08
# step 99400, training accuracy 0.16
# step 99500, training accuracy 0.1
# step 99600, training accuracy 0.08
# step 99700, training accuracy 0.14
# step 99800, training accuracy 0.12
# step 99900, training accuracy 0.22
# step 100000, training accuracy 0.1
# step 100100, training accuracy 0.08
# step 100200, training accuracy 0.06
# step 100300, training accuracy 0.08
# step 100400, training accuracy 0.12
# step 100500, training accuracy 0.08
# step 100600, training accuracy 0.1
# step 100700, training accuracy 0.14
# step 100800, training accuracy 0.1
# step 100900, training accuracy 0.1
# step 101000, training accuracy 0.1
# step 101100, training accuracy 0.06
# step 101200, training accuracy 0.18
# step 101300, training accuracy 0.12
# step 101400, training accuracy 0.12
# step 101500, training accuracy 0.08
# step 101600, training accuracy 0.12
# step 101700, training accuracy 0.08
# step 101800, training accuracy 0.1
# step 101900, training accuracy 0.04
# step 102000, training accuracy 0.12
# step 102100, training accuracy 0.18
# step 102200, training accuracy 0.08
# step 102300, training accuracy 0.04
# step 102400, training accuracy 0.06
# step 102500, training accuracy 0.06
# step 102600, training accuracy 0.1
# step 102700, training accuracy 0.06
# step 102800, training accuracy 0.1
# step 102900, training accuracy 0.24
# step 103000, training accuracy 0.08
# step 103100, training accuracy 0.08
# step 103200, training accuracy 0.1
# step 103300, training accuracy 0.16
# step 103400, training accuracy 0.08
# step 103500, training accuracy 0.16
# step 103600, training accuracy 0.1
# step 103700, training accuracy 0.06
# step 103800, training accuracy 0.14
# step 103900, training accuracy 0.1
# step 104000, training accuracy 0.1
# step 104100, training accuracy 0.12
# step 104200, training accuracy 0.12
# step 104300, training accuracy 0.04
# step 104400, training accuracy 0.04
# step 104500, training accuracy 0.06
# step 104600, training accuracy 0.2
# step 104700, training accuracy 0.12
# step 104800, training accuracy 0.14
# step 104900, training accuracy 0.08
# step 105000, training accuracy 0.14
# step 105100, training accuracy 0.06
# step 105200, training accuracy 0.04
# step 105300, training accuracy 0.08
# step 105400, training accuracy 0.14
# step 105500, training accuracy 0.14
# step 105600, training accuracy 0.06
# step 105700, training accuracy 0.1
# step 105800, training accuracy 0
# step 105900, training accuracy 0.12
# step 106000, training accuracy 0.12
# step 106100, training accuracy 0.04
# step 106200, training accuracy 0.1
# step 106300, training accuracy 0.14
# step 106400, training accuracy 0.14
# step 106500, training accuracy 0.14
# step 106600, training accuracy 0.14
# step 106700, training accuracy 0.16
# step 106800, training accuracy 0.06
# step 106900, training accuracy 0.06
# step 107000, training accuracy 0.18
# step 107100, training accuracy 0.14
# step 107200, training accuracy 0.08
# step 107300, training accuracy 0.08
# step 107400, training accuracy 0.14
# step 107500, training accuracy 0.1
# step 107600, training accuracy 0.1
# step 107700, training accuracy 0.12
# step 107800, training accuracy 0.08
# step 107900, training accuracy 0.12
# step 108000, training accuracy 0.1
# step 108100, training accuracy 0.18
# step 108200, training accuracy 0.14
# step 108300, training accuracy 0.18
# step 108400, training accuracy 0.02
# step 108500, training accuracy 0.12
# step 108600, training accuracy 0.08
# step 108700, training accuracy 0.12
# step 108800, training accuracy 0.08
# step 108900, training accuracy 0.08
# step 109000, training accuracy 0.12
# step 109100, training accuracy 0.1
# step 109200, training accuracy 0.18
# step 109300, training accuracy 0.08
# step 109400, training accuracy 0.1
# step 109500, training accuracy 0.1
# step 109600, training accuracy 0.04
# step 109700, training accuracy 0.04
# step 109800, training accuracy 0.18
# step 109900, training accuracy 0.06
# step 110000, training accuracy 0.06
# step 110100, training accuracy 0.1
# step 110200, training accuracy 0.1
# step 110300, training accuracy 0.12
# step 110400, training accuracy 0.16
# step 110500, training accuracy 0.06
# step 110600, training accuracy 0.14
# step 110700, training accuracy 0.08
# step 110800, training accuracy 0.06
# step 110900, training accuracy 0.12
# step 111000, training accuracy 0.12
# step 111100, training accuracy 0.1
# step 111200, training accuracy 0.16
# step 111300, training accuracy 0.1
# step 111400, training accuracy 0.1
# step 111500, training accuracy 0.08
# step 111600, training accuracy 0.06
# step 111700, training accuracy 0.12
# step 111800, training accuracy 0.06
# step 111900, training accuracy 0.12
# step 112000, training accuracy 0.08
# step 112100, training accuracy 0.02
# step 112200, training accuracy 0.1
# step 112300, training accuracy 0.08
# step 112400, training accuracy 0.12
# step 112500, training accuracy 0.1
# step 112600, training accuracy 0.14
# step 112700, training accuracy 0.1
# step 112800, training accuracy 0.08
# step 112900, training accuracy 0.14
# step 113000, training accuracy 0.16
# step 113100, training accuracy 0.06
# step 113200, training accuracy 0.14
# step 113300, training accuracy 0.04
# step 113400, training accuracy 0.12
# step 113500, training accuracy 0.12
# step 113600, training accuracy 0.08
# step 113700, training accuracy 0.12
# step 113800, training accuracy 0.06
# step 113900, training accuracy 0.14
# step 114000, training accuracy 0.06
# step 114100, training accuracy 0.1
# step 114200, training accuracy 0.1
# step 114300, training accuracy 0.1
# step 114400, training accuracy 0.1
# step 114500, training accuracy 0
# step 114600, training accuracy 0.12
# step 114700, training accuracy 0.12
# step 114800, training accuracy 0.06
# step 114900, training accuracy 0.14
# step 115000, training accuracy 0.16
# step 115100, training accuracy 0.1
# step 115200, training accuracy 0.06
# step 115300, training accuracy 0.04
# step 115400, training accuracy 0.08
# step 115500, training accuracy 0.06
# step 115600, training accuracy 0.06
# step 115700, training accuracy 0.1
# step 115800, training accuracy 0.16
# step 115900, training accuracy 0.1
# step 116000, training accuracy 0.1
# step 116100, training accuracy 0.02
# step 116200, training accuracy 0.12
# step 116300, training accuracy 0.12
# step 116400, training accuracy 0.06
# step 116500, training accuracy 0.08
# step 116600, training accuracy 0.1
# step 116700, training accuracy 0.18
# step 116800, training accuracy 0.12
# step 116900, training accuracy 0.1
# step 117000, training accuracy 0.08
# step 117100, training accuracy 0.06
# step 117200, training accuracy 0.08
# step 117300, training accuracy 0.12
# step 117400, training accuracy 0.08
# step 117500, training accuracy 0.12
# step 117600, training accuracy 0.14
# step 117700, training accuracy 0.1
# step 117800, training accuracy 0.12
# step 117900, training accuracy 0.06
# step 118000, training accuracy 0.12
# step 118100, training accuracy 0.08
# step 118200, training accuracy 0.06
# step 118300, training accuracy 0
# step 118400, training accuracy 0.1
# step 118500, training accuracy 0.14
# step 118600, training accuracy 0.06
# step 118700, training accuracy 0.12
# step 118800, training accuracy 0.1
# step 118900, training accuracy 0.1
# step 119000, training accuracy 0.1
# step 119100, training accuracy 0.18
# step 119200, training accuracy 0.12
# step 119300, training accuracy 0.1
# step 119400, training accuracy 0.08
# step 119500, training accuracy 0.1
# step 119600, training accuracy 0.16
# step 119700, training accuracy 0.04
# step 119800, training accuracy 0.06
# step 119900, training accuracy 0.08
# step 120000, training accuracy 0.08
# step 120100, training accuracy 0.08
# step 120200, training accuracy 0.12
# step 120300, training accuracy 0.08
# step 120400, training accuracy 0.04
# step 120500, training accuracy 0.1
# step 120600, training accuracy 0.06
# step 120700, training accuracy 0.16
# step 120800, training accuracy 0.06
# step 120900, training accuracy 0.06
# step 121000, training accuracy 0.14
# step 121100, training accuracy 0.16
# step 121200, training accuracy 0.14
# step 121300, training accuracy 0.1
# step 121400, training accuracy 0.08
# step 121500, training accuracy 0.02
# step 121600, training accuracy 0.06
# step 121700, training accuracy 0.14
# step 121800, training accuracy 0.12
# step 121900, training accuracy 0.06
# step 122000, training accuracy 0.12
# step 122100, training accuracy 0.04
# step 122200, training accuracy 0.1
# step 122300, training accuracy 0.02
# step 122400, training accuracy 0.16
# step 122500, training accuracy 0.1
# step 122600, training accuracy 0.08
# step 122700, training accuracy 0.16
# step 122800, training accuracy 0.08
# step 122900, training accuracy 0.06
# step 123000, training accuracy 0.08
# step 123100, training accuracy 0.12
# step 123200, training accuracy 0.04
# step 123300, training accuracy 0.08
# step 123400, training accuracy 0.12
# step 123500, training accuracy 0.02
# step 123600, training accuracy 0.06
# step 123700, training accuracy 0.16
# step 123800, training accuracy 0.12
# step 123900, training accuracy 0.08
# step 124000, training accuracy 0.14
# step 124100, training accuracy 0.12
# step 124200, training accuracy 0.08
# step 124300, training accuracy 0.1
# step 124400, training accuracy 0.06
# step 124500, training accuracy 0.2
# step 124600, training accuracy 0.14
# step 124700, training accuracy 0.08
# step 124800, training accuracy 0.04
# step 124900, training accuracy 0.12
# step 125000, training accuracy 0.06
# step 125100, training accuracy 0.06
# step 125200, training accuracy 0.12
# step 125300, training accuracy 0.08
# step 125400, training accuracy 0.14
# step 125500, training accuracy 0.14
# step 125600, training accuracy 0.06
# step 125700, training accuracy 0.14
# step 125800, training accuracy 0.1
# step 125900, training accuracy 0.12
# step 126000, training accuracy 0.08
# step 126100, training accuracy 0.1
# step 126200, training accuracy 0.1
# step 126300, training accuracy 0.08
# step 126400, training accuracy 0.04
# step 126500, training accuracy 0.16
# step 126600, training accuracy 0.14
# step 126700, training accuracy 0.1
# step 126800, training accuracy 0.12
# step 126900, training accuracy 0.08
# step 127000, training accuracy 0.06
# step 127100, training accuracy 0.06
# step 127200, training accuracy 0.14
# step 127300, training accuracy 0.04
# step 127400, training accuracy 0.08
# step 127500, training accuracy 0.14
# step 127600, training accuracy 0.12
# step 127700, training accuracy 0.06
# step 127800, training accuracy 0.04
# step 127900, training accuracy 0.16
# step 128000, training accuracy 0.12
# step 128100, training accuracy 0.12
# step 128200, training accuracy 0.12
# step 128300, training accuracy 0.02
# step 128400, training accuracy 0.08
# step 128500, training accuracy 0.14
# step 128600, training accuracy 0.06
# step 128700, training accuracy 0.1
# step 128800, training accuracy 0.04
# step 128900, training accuracy 0.16
# step 129000, training accuracy 0.06
# step 129100, training accuracy 0.08
# step 129200, training accuracy 0.08
# step 129300, training accuracy 0.04
# step 129400, training accuracy 0.08
# step 129500, training accuracy 0.06
# step 129600, training accuracy 0.08
# step 129700, training accuracy 0.02
# step 129800, training accuracy 0.1
# step 129900, training accuracy 0.14
# step 130000, training accuracy 0.16
# step 130100, training accuracy 0.1
# step 130200, training accuracy 0.12
# step 130300, training accuracy 0.1
# step 130400, training accuracy 0.08
# step 130500, training accuracy 0.04
# step 130600, training accuracy 0.12
# step 130700, training accuracy 0.08
# step 130800, training accuracy 0.1
# step 130900, training accuracy 0.18
# step 131000, training accuracy 0.04
# step 131100, training accuracy 0.1
# step 131200, training accuracy 0.18
# step 131300, training accuracy 0.06
# step 131400, training accuracy 0.12
# step 131500, training accuracy 0.04
# step 131600, training accuracy 0.08
# step 131700, training accuracy 0.02
# step 131800, training accuracy 0.14
# step 131900, training accuracy 0.08
# step 132000, training accuracy 0.08
# step 132100, training accuracy 0.08
# step 132200, training accuracy 0.12
# step 132300, training accuracy 0.1
# step 132400, training accuracy 0.08
# step 132500, training accuracy 0.1
# step 132600, training accuracy 0.08
# step 132700, training accuracy 0.08
# step 132800, training accuracy 0.04
# step 132900, training accuracy 0.1
# step 133000, training accuracy 0.04
# step 133100, training accuracy 0.02
# step 133200, training accuracy 0.06
# step 133300, training accuracy 0.14
# step 133400, training accuracy 0.06
# step 133500, training accuracy 0.12
# step 133600, training accuracy 0.16
# step 133700, training accuracy 0.12
# step 133800, training accuracy 0.08
# step 133900, training accuracy 0.12
# step 134000, training accuracy 0.16
# step 134100, training accuracy 0.14
# step 134200, training accuracy 0.12
# step 134300, training accuracy 0.1
# step 134400, training accuracy 0.12
# step 134500, training accuracy 0.08
# step 134600, training accuracy 0.2
# step 134700, training accuracy 0.08
# step 134800, training accuracy 0.08
# step 134900, training accuracy 0.14
# step 135000, training accuracy 0.16
# step 135100, training accuracy 0.06
# step 135200, training accuracy 0.08
# step 135300, training accuracy 0.04
# step 135400, training accuracy 0.14
# step 135500, training accuracy 0.04
# step 135600, training accuracy 0.02
# step 135700, training accuracy 0.1
# step 135800, training accuracy 0.1
# step 135900, training accuracy 0.12
# step 136000, training accuracy 0.08
# step 136100, training accuracy 0.1
# step 136200, training accuracy 0.12
# step 136300, training accuracy 0.08
# step 136400, training accuracy 0.06
# step 136500, training accuracy 0.2
# step 136600, training accuracy 0.06
# step 136700, training accuracy 0.1
# step 136800, training accuracy 0.04
# step 136900, training accuracy 0.1
# step 137000, training accuracy 0.06
# step 137100, training accuracy 0.1
# step 137200, training accuracy 0.1
# step 137300, training accuracy 0.1
# step 137400, training accuracy 0.1
# step 137500, training accuracy 0.14
# step 137600, training accuracy 0.2
# step 137700, training accuracy 0.1
# step 137800, training accuracy 0.1
# step 137900, training accuracy 0.06
# step 138000, training accuracy 0.16
# step 138100, training accuracy 0.04
# step 138200, training accuracy 0.16
# step 138300, training accuracy 0.12
# step 138400, training accuracy 0.22
# step 138500, training accuracy 0.1
# step 138600, training accuracy 0.08
# step 138700, training accuracy 0.1
# step 138800, training accuracy 0.04
# step 138900, training accuracy 0.08
# step 139000, training accuracy 0.1
# ...
# step 155400, training accuracy 0.04
# step 155500, training accuracy 0.1
# step 155600, training accuracy 0.08
# step 155700, training accuracy 0.08
# step 155800, training accuracy 0.1
# step 155900, training accuracy 0.14
# step 156000, training accuracy 0.16
# step 156100, training accuracy 0.06
# step 156200, training accuracy 0.04
# step 156300, training accuracy 0.2
# step 156400, training accuracy 0.08
# step 156500, training accuracy 0.08
# step 156600, training accuracy 0.06
# step 156700, training accuracy 0.08
# step 156800, training accuracy 0.02
# step 156900, training accuracy 0.04
# step 157000, training accuracy 0.08
# step 157100, training accuracy 0.1
# step 157200, training accuracy 0.1
# step 157300, training accuracy 0.08
# step 157400, training accuracy 0.16
# step 157500, training accuracy 0.12
# step 157600, training accuracy 0.14
# step 157700, training accuracy 0.14
# step 157800, training accuracy 0.1
# step 157900, training accuracy 0.14
# step 158000, training accuracy 0.18
# step 158100, training accuracy 0.22
# step 158200, training accuracy 0.1
# step 158300, training accuracy 0.12
# step 158400, training accuracy 0.06
# step 158500, training accuracy 0.18
# step 158600, training accuracy 0.14
# step 158700, training accuracy 0.2
# step 158800, training accuracy 0.12
# step 158900, training accuracy 0.06
# step 159000, training accuracy 0.14
# step 159100, training accuracy 0.14
# step 159200, training accuracy 0.18
# step 159300, training accuracy 0.02
# step 159400, training accuracy 0.1
# step 159500, training accuracy 0.1
# step 159600, training accuracy 0.04
# step 159700, training accuracy 0.16
# step 159800, training accuracy 0.14
# step 159900, training accuracy 0.2
# step 160000, training accuracy 0.04
# step 160100, training accuracy 0.06
# step 160200, training accuracy 0.08
# step 160300, training accuracy 0.18
# step 160400, training accuracy 0.16
# step 160500, training accuracy 0.04
# step 160600, training accuracy 0.12
# step 160700, training accuracy 0.1
# step 160800, training accuracy 0.04
# step 160900, training accuracy 0.1
# step 161000, training accuracy 0.04
# step 161100, training accuracy 0.06
# step 161200, training accuracy 0.04
# step 161300, training accuracy 0.14
# step 161400, training accuracy 0.14
# step 161500, training accuracy 0.12
# step 161600, training accuracy 0.04
# step 161700, training accuracy 0.04
# step 161800, training accuracy 0.1
# step 161900, training accuracy 0.14
# step 162000, training accuracy 0.1
# step 162100, training accuracy 0.16
# step 162200, training accuracy 0.1
# step 162300, training accuracy 0.06
# step 162400, training accuracy 0.12
# step 162500, training accuracy 0.1
# step 162600, training accuracy 0.04
# step 162700, training accuracy 0.08
# step 162800, training accuracy 0.08
# step 162900, training accuracy 0.04
# step 163000, training accuracy 0.08
# step 163100, training accuracy 0.1
# step 163200, training accuracy 0.1
# step 163300, training accuracy 0.1
# step 163400, training accuracy 0.02
# step 163500, training accuracy 0.02
# step 163600, training accuracy 0.06
# step 163700, training accuracy 0.14
# step 163800, training accuracy 0.14
# step 163900, training accuracy 0.14
# step 164000, training accuracy 0.1
# step 164100, training accuracy 0.18
# step 164200, training accuracy 0.18
# step 164300, training accuracy 0.1
# step 164400, training accuracy 0.1
# step 164500, training accuracy 0.08
# step 164600, training accuracy 0.06
# step 164700, training accuracy 0.04
# step 164800, training accuracy 0.14
# step 164900, training accuracy 0.06
# step 165000, training accuracy 0.08
# step 165100, training accuracy 0.1
# step 165200, training accuracy 0.06
# step 165300, training accuracy 0.12
# step 165400, training accuracy 0.12
# step 165500, training accuracy 0.08
# step 165600, training accuracy 0.06
# step 165700, training accuracy 0.06
# step 165800, training accuracy 0.1
# step 165900, training accuracy 0.16
# step 166000, training accuracy 0.14
# step 166100, training accuracy 0.04
# step 166200, training accuracy 0.04
# step 166300, training accuracy 0.1
# step 166400, training accuracy 0.14
# step 166500, training accuracy 0.14
# step 166600, training accuracy 0.2
# step 166700, training accuracy 0.12
# step 166800, training accuracy 0.12
# step 166900, training accuracy 0.1
# step 167000, training accuracy 0.04
# step 167100, training accuracy 0.14
# step 167200, training accuracy 0.16
# step 167300, training accuracy 0.14
# step 167400, training accuracy 0.1
# step 167500, training accuracy 0.08
# step 167600, training accuracy 0.12
# step 167700, training accuracy 0.2
# step 167800, training accuracy 0.06
# step 167900, training accuracy 0.2
# step 168000, training accuracy 0.08
# step 168100, training accuracy 0.04
# step 168200, training accuracy 0.1
# step 168300, training accuracy 0.14
# step 168400, training accuracy 0.08
# step 168500, training accuracy 0.18
# step 168600, training accuracy 0.14
# step 168700, training accuracy 0.12
# step 168800, training accuracy 0.06
# step 168900, training accuracy 0.02
# step 169000, training accuracy 0.14
# step 169100, training accuracy 0.06
# step 169200, training accuracy 0.08
# step 169300, training accuracy 0.08
# step 169400, training accuracy 0.08
# step 169500, training accuracy 0.08
# step 169600, training accuracy 0.18
# step 169700, training accuracy 0.04
# step 169800, training accuracy 0.08
# step 169900, training accuracy 0.1
# step 170000, training accuracy 0.12
# step 170100, training accuracy 0.14
# step 170200, training accuracy 0.1
# step 170300, training accuracy 0.14
# step 170400, training accuracy 0.04
# step 170500, training accuracy 0.14
# step 170600, training accuracy 0.14
# step 170700, training accuracy 0.08
# step 170800, training accuracy 0.1
# step 170900, training accuracy 0.1
# step 171000, training accuracy 0.06
# step 171100, training accuracy 0.08
# step 171200, training accuracy 0.1
# step 171300, training accuracy 0.08
# step 171400, training accuracy 0.14
# step 171500, training accuracy 0.04
# step 171600, training accuracy 0.08
# step 171700, training accuracy 0.18
# step 171800, training accuracy 0.08
# step 171900, training accuracy 0.04
# step 172000, training accuracy 0.12
# step 172100, training accuracy 0.02
# step 172200, training accuracy 0.08
# step 172300, training accuracy 0.06
# step 172400, training accuracy 0.08
# step 172500, training accuracy 0.14
# step 172600, training accuracy 0.06
# step 172700, training accuracy 0.12
# step 172800, training accuracy 0.12
# step 172900, training accuracy 0.12
# step 173000, training accuracy 0.12
# step 173100, training accuracy 0.06
# step 173200, training accuracy 0.12
# step 173300, training accuracy 0.12
# step 173400, training accuracy 0.12
# step 173500, training accuracy 0.14
# step 173600, training accuracy 0.02
# step 173700, training accuracy 0.08
# step 173800, training accuracy 0.12
# step 173900, training accuracy 0.12
# step 174000, training accuracy 0.08
# step 174100, training accuracy 0.1
# step 174200, training accuracy 0.16
# step 174300, training accuracy 0.12
# step 174400, training accuracy 0.1
# step 174500, training accuracy 0.06
# step 174600, training accuracy 0.02
# step 174700, training accuracy 0.1
# step 174800, training accuracy 0.12
# step 174900, training accuracy 0.06
# step 175000, training accuracy 0.08
# step 175100, training accuracy 0.12
# step 175200, training accuracy 0.06
# step 175300, training accuracy 0.18
# step 175400, training accuracy 0.14
# step 175500, training accuracy 0.06
# step 175600, training accuracy 0.02
# step 175700, training accuracy 0.1
# step 175800, training accuracy 0.08
# step 175900, training accuracy 0.14
# step 176000, training accuracy 0.02
# step 176100, training accuracy 0.1
# step 176200, training accuracy 0.06
# step 176300, training accuracy 0.06
# step 176400, training accuracy 0.16
# step 176500, training accuracy 0.14
# step 176600, training accuracy 0.04
# step 176700, training accuracy 0.08
# step 176800, training accuracy 0.08
# step 176900, training accuracy 0.08
# step 177000, training accuracy 0.16
# step 177100, training accuracy 0.14
# step 177200, training accuracy 0.1
# step 177300, training accuracy 0.18
# step 177400, training accuracy 0.08
# step 177500, training accuracy 0.14
# step 177600, training accuracy 0.06
# step 177700, training accuracy 0.08
# step 177800, training accuracy 0.1
# step 177900, training accuracy 0.08
# step 178000, training accuracy 0.06
# step 178100, training accuracy 0.08
# step 178200, training accuracy 0.1
# step 178300, training accuracy 0.06
# step 178400, training accuracy 0.12
# step 178500, training accuracy 0.14
# step 178600, training accuracy 0.06
# step 178700, training accuracy 0.12
# step 178800, training accuracy 0.16
# step 178900, training accuracy 0.1
# step 179000, training accuracy 0.08
# step 179100, training accuracy 0.04
# step 179200, training accuracy 0.1
# step 179300, training accuracy 0.12
# step 179400, training accuracy 0.14
# step 179500, training accuracy 0.22
# step 179600, training accuracy 0.02
# step 179700, training accuracy 0.14
# step 179800, training accuracy 0.22
# step 179900, training accuracy 0.14
# step 180000, training accuracy 0.12
# step 180100, training accuracy 0.06
# step 180200, training accuracy 0.08
# step 180300, training accuracy 0.08
# step 180400, training accuracy 0.08
# step 180500, training accuracy 0.1
# step 180600, training accuracy 0.18
# step 180700, training accuracy 0.04
# step 180800, training accuracy 0.14
# step 180900, training accuracy 0.1
# step 181000, training accuracy 0.14
# step 181100, training accuracy 0.2
# step 181200, training accuracy 0.16
# step 181300, training accuracy 0.1
# step 181400, training accuracy 0.1
# step 181500, training accuracy 0.16
# step 181600, training accuracy 0.12
# step 181700, training accuracy 0.08
# step 181800, training accuracy 0.12
# step 181900, training accuracy 0.1
# step 182000, training accuracy 0.08
# step 182100, training accuracy 0.1
# step 182200, training accuracy 0.12
# step 182300, training accuracy 0.14
# step 182400, training accuracy 0.14
# step 182500, training accuracy 0.1
# step 182600, training accuracy 0.1
# step 182700, training accuracy 0.12
# step 182800, training accuracy 0.14
# step 182900, training accuracy 0.16
# step 183000, training accuracy 0.08
# step 183100, training accuracy 0.08
# step 183200, training accuracy 0.06
# step 183300, training accuracy 0.22
# step 183400, training accuracy 0.1
# step 183500, training accuracy 0.06
# step 183600, training accuracy 0.2
# step 183700, training accuracy 0.06
# step 183800, training accuracy 0.2
# step 183900, training accuracy 0.14
# step 184000, training accuracy 0.12
# step 184100, training accuracy 0.08
# step 184200, training accuracy 0.14
# step 184300, training accuracy 0.1
# step 184400, training accuracy 0.1
# step 184500, training accuracy 0.08
# step 184600, training accuracy 0.1
# step 184700, training accuracy 0.1
# step 184800, training accuracy 0.06
# step 184900, training accuracy 0.02
# step 185000, training accuracy 0.08
# step 185100, training accuracy 0.08
# step 185200, training accuracy 0.1
# step 185300, training accuracy 0.04
# step 185400, training accuracy 0.1
# step 185500, training accuracy 0.1
# step 185600, training accuracy 0.02
# step 185700, training accuracy 0.08
# step 185800, training accuracy 0.06
# step 185900, training accuracy 0.04
# step 186000, training accuracy 0.04
# step 186100, training accuracy 0.12
# step 186200, training accuracy 0.1
# step 186300, training accuracy 0.04
# step 186400, training accuracy 0.08
# step 186500, training accuracy 0.06
# step 186600, training accuracy 0.12
# step 186700, training accuracy 0.16
# step 186800, training accuracy 0.08
# step 186900, training accuracy 0.06
# step 187000, training accuracy 0.1
# step 187100, training accuracy 0.1
# step 187200, training accuracy 0.1
# step 187300, training accuracy 0.1
# step 187400, training accuracy 0.16
# step 187500, training accuracy 0.06
# step 187600, training accuracy 0.08
# step 187700, training accuracy 0.02
# step 187800, training accuracy 0.1
# step 187900, training accuracy 0.12
# step 188000, training accuracy 0.08
# step 188100, training accuracy 0.08
# step 188200, training accuracy 0.06
# step 188300, training accuracy 0.1
# step 188400, training accuracy 0.14
# step 188500, training accuracy 0.16
# step 188600, training accuracy 0.24
# step 188700, training accuracy 0.12
# step 188800, training accuracy 0.06
# step 188900, training accuracy 0.04
# step 189000, training accuracy 0.14
# step 189100, training accuracy 0.12
# step 189200, training accuracy 0.02
# step 189300, training accuracy 0.12
# step 189400, training accuracy 0.16
# step 189500, training accuracy 0.06
# step 189600, training accuracy 0.04
# step 189700, training accuracy 0.14
# step 189800, training accuracy 0.1
# step 189900, training accuracy 0.04
# step 190000, training accuracy 0.14
# step 190100, training accuracy 0.08
# step 190200, training accuracy 0.06
# step 190300, training accuracy 0.04
# step 190400, training accuracy 0.14
# step 190500, training accuracy 0.06
# step 190600, training accuracy 0.08
# step 190700, training accuracy 0.02
# step 190800, training accuracy 0.06
# step 190900, training accuracy 0.08
# step 191000, training accuracy 0.04
# step 191100, training accuracy 0.14
# step 191200, training accuracy 0.12
# step 191300, training accuracy 0.12
# step 191400, training accuracy 0.12
# step 191500, training accuracy 0.14
# step 191600, training accuracy 0.12
# step 191700, training accuracy 0.14
# step 191800, training accuracy 0.12
# step 191900, training accuracy 0.08
# step 192000, training accuracy 0.08
# step 192100, training accuracy 0.14
# step 192200, training accuracy 0.08
# step 192300, training accuracy 0.1
# step 192400, training accuracy 0.1
# step 192500, training accuracy 0.12
# step 192600, training accuracy 0.12
# step 192700, training accuracy 0.1
# step 192800, training accuracy 0.02
# step 192900, training accuracy 0.12
# step 193000, training accuracy 0.06
# step 193100, training accuracy 0.16
# step 193200, training accuracy 0.12
# step 193300, training accuracy 0.14
# step 193400, training accuracy 0.1
# step 193500, training accuracy 0.08
# step 193600, training accuracy 0.06
# step 193700, training accuracy 0.08
# step 193800, training accuracy 0.1
# step 193900, training accuracy 0.06
# step 194000, training accuracy 0.1
# step 194100, training accuracy 0.06
# step 194200, training accuracy 0.14
# step 194300, training accuracy 0.2
# step 194400, training accuracy 0.12
# step 194500, training accuracy 0.04
# step 194600, training accuracy 0.1
# step 194700, training accuracy 0.12
# step 194800, training accuracy 0.18
# step 194900, training accuracy 0.1
# step 195000, training accuracy 0.12
# step 195100, training accuracy 0.12
# step 195200, training accuracy 0.04
# step 195300, training accuracy 0.06
# step 195400, training accuracy 0.06
# step 195500, training accuracy 0.12
# step 195600, training accuracy 0.1
# step 195700, training accuracy 0.16
# step 195800, training accuracy 0.12
# step 195900, training accuracy 0.06
# step 196000, training accuracy 0.2
# step 196100, training accuracy 0.12
# step 196200, training accuracy 0
# step 196300, training accuracy 0.12
# step 196400, training accuracy 0.12
# step 196500, training accuracy 0.04
# step 196600, training accuracy 0.08
# step 196700, training accuracy 0.16
# step 196800, training accuracy 0.08
# step 196900, training accuracy 0.08
# step 197000, training accuracy 0.1
# step 197100, training accuracy 0.2
# step 197200, training accuracy 0.04
# step 197300, training accuracy 0.04
# step 197400, training accuracy 0.14
# step 197500, training accuracy 0.16
# step 197600, training accuracy 0.14
# step 197700, training accuracy 0.1
# step 197800, training accuracy 0.1
# step 197900, training accuracy 0.06
# step 198000, training accuracy 0.1
# step 198100, training accuracy 0.1
# step 198200, training accuracy 0.06
# step 198300, training accuracy 0.04
# step 198400, training accuracy 0.08
# step 198500, training accuracy 0.14
# step 198600, training accuracy 0.1
# step 198700, training accuracy 0.04
# step 198800, training accuracy 0.1
# step 198900, training accuracy 0.14
# step 199000, training accuracy 0.06
# step 199100, training accuracy 0.12
# step 199200, training accuracy 0.16
# step 199300, training accuracy 0.1
# step 199400, training accuracy 0.1
# step 199500, training accuracy 0.04
# step 199600, training accuracy 0.08
# step 199700, training accuracy 0.1
# step 199800, training accuracy 0.1
# step 199900, training accuracy 0
# test accuravy 0.098
